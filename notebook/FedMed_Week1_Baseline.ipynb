# %%
import os
import torch

print("Current directory:")
print(os.getcwd())

print("\nPyTorch:")
print(torch.__version__)

print("\nCUDA available:")
print(torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Current directory:
# /content
#
# PyTorch:
# 2.11.0+cu128
#
# CUDA available:
# True
# GPU: Tesla T4

# %%
import os
print(os.getcwd())
print(os.listdir("."))
# Out:
# /content
# ['.config', 'sample_data']

# %%
import os

os.makedirs("/content/FedMed/data/brats", exist_ok=True)
os.makedirs("/content/FedMed/centralized", exist_ok=True)
os.makedirs("/content/FedMed/federated", exist_ok=True)

print("FedMed workspace created.")
# Out:
# FedMed workspace created.

# %%
# !find /content/FedMed -maxdepth 2 -type d
# Out:
# /content/FedMed
# /content/FedMed/federated
# /content/FedMed/centralized
# /content/FedMed/data
# /content/FedMed/data/brats
